# %%
# Importando pandas
import pandas as pd


# Importando os dados para um dataframe
df = pd.read_csv('ocorrencia_2010_2020.csv', delimiter=';',
                 index_col='codigo_ocorrencia')


# Vendo as primeiras entradas
df.head()
# Out:
#                    codigo_ocorrencia1  ...  ocorrencia_saida_pista
# codigo_ocorrencia                      ...
# 40211                           40211  ...                     NÃO
# 40349                           40349  ...                     NÃO
# 40351                           40351  ...                     NÃO
# 39527                           39527  ...                     NÃO
# 40324                           40324  ...                     NÃO
#
# [5 rows x 21 columns]

# %% [markdown]
# Criar um dicionário apenas com as colunas que serão usadas e os nomes padronizados para cada uma dessas colunas.

# %%
# Selecionando as colunas e renomeando-as as que serão utilizadas, de fato
columns = {
    'ocorrencia_latitude': 'latitude',
    'ocorrencia_longitude': 'longitude',
    'ocorrencia_dia': 'data',
    'ocorrencia_classificacao': 'classificacao',
    'ocorrencia_aerodromo': 'aerodromo',
    'ocorrencia_cidade': 'cidade',
    'investigacao_status': 'status',
    'divulgacao_relatorio_numero': 'relatorio_numero',
    'total_aeronaves_envolvidas': 'aeronaves_envolvidas',
}

# %%
df = df.rename(columns=columns)
df.head()
# Out:
#                    codigo_ocorrencia1  ...  ocorrencia_saida_pista
# codigo_ocorrencia                      ...
# 40211                           40211  ...                     NÃO
# 40349                           40349  ...                     NÃO
# 40351                           40351  ...                     NÃO
# 39527                           39527  ...                     NÃO
# 40324                           40324  ...                     NÃO
#
# [5 rows x 21 columns]

# %%
# tentando dar um drop nas colunas codigo_ocorrencia1, ..., classificacao
df.drop(['codigo_ocorrencia1', 'codigo_ocorrencia2', 'codigo_ocorrencia3',
       'codigo_ocorrencia4'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                   classificacao  ... ocorrencia_saida_pista
# codigo_ocorrencia                ...
# 40211                 INCIDENTE  ...                    NÃO
# 40349                 INCIDENTE  ...                    NÃO
# 40351                 INCIDENTE  ...                    NÃO
# 39527                  ACIDENTE  ...                    NÃO
# 40324                 INCIDENTE  ...                    NÃO
#
# [5 rows x 17 columns]

# %% [markdown]
# Converter o formato da coluna `data` para o formato `datetime`.

# %%
df.data = df.data + " " + df.ocorrencia_hora
df.data = pd.to_datetime(df.data)

# %%
# visualizando a conversao
df.data
# Out:
# codigo_ocorrencia
# 40211   2010-03-01 12:00:00
# 40349   2010-03-01 11:05:00
# 40351   2010-03-01 03:00:00
# 39527   2010-04-01 17:30:00
# 40324   2010-05-01 19:25:00
#                 ...
# 79804   2020-12-29 19:00:00
# 79757   2020-12-30 18:30:00
# 79802   2020-12-30 00:54:00
# 79756   2020-12-31 09:00:00
# 79844   2020-12-31 13:24:00
# Name: data, Length: 5752, dtype: datetime64[ns]

# %% [markdown]
# Selecionar apenas as colunas que serão utilizadas no app do `Streamlit` (será o retorno da função `load_data()`).

# %%
df[list(columns.values())]
# Out:
#                          latitude  ... aeronaves_envolvidas
# codigo_ocorrencia                  ...
# 40211                         ***  ...                    1
# 40349                         NaN  ...                    1
# 40351                         NaN  ...                    1
# 39527              -13.1066666667  ...                    1
# 40324                         NaN  ...                    1
# ...                           ...  ...                  ...
# 79804              -23.0069444444  ...                    1
# 79757                  -10.804722  ...                    1
# 79802                      -22.81  ...                    1
# 79756                  -22.507222  ...                    1
# 79844                    -22,9875  ...                    1
#
# [5752 rows x 9 columns]

# %% [markdown]
# ---

# %%
# Pega os diferentes tipos de classificação, sem repetição
df['classificacao'].unique()


# Converte para lsita
df['classificacao'].unique().tolist()
# Out:
# ['INCIDENTE', 'ACIDENTE', 'INCIDENTE GRAVE']

# %%
lista_classificacao = list(df['classificacao'].unique())

# %%
labels = list(df.classificacao.unique())

labels
# Out:
# ['INCIDENTE', 'ACIDENTE', 'INCIDENTE GRAVE']

# %%
df[(df.data.dt.year == 2017) & (df.classificacao.isin(['INCIDENTE']))]
# Out:
#                   classificacao  ... ocorrencia_saida_pista
# codigo_ocorrencia                ...
# 66199                 INCIDENTE  ...                    NÃO
# 66250                 INCIDENTE  ...                    NÃO
# 66261                 INCIDENTE  ...                    NÃO
# 66271                 INCIDENTE  ...                    NÃO
# 66270                 INCIDENTE  ...                    NÃO
# ...                         ...  ...                    ...
# 77211                 INCIDENTE  ...                    NÃO
# 77208                 INCIDENTE  ...                    NÃO
# 77209                 INCIDENTE  ...                    NÃO
# 77205                 INCIDENTE  ...                    NÃO
# 77203                 INCIDENTE  ...                    NÃO
#
# [231 rows x 17 columns]

# %%
dropando = df['longitude'] == '***'
df.replace(df['longitude'] = '***', 'NaN')
#print(sum(dropando), df['longitude'].shape[0])
# Out:
#   File "<ipython-input-97-62ddb643869e>", line 2
#     df.replace(df['longitude'] = '***', 'NaN')
#               ^
# SyntaxError: keyword can't be an expression

# %%
df['longitude']
# Out:
# codigo_ocorrencia
# 40211                ***
# 40349                NaN
# 40351                NaN
# 39527     -55.9930555556
# 40324                NaN
#               ...
# 79804     -47.1344444444
# 79757         -49.756389
# 79802    -43.25055555555
# 79756         -54.364167
# 79844             -43,37
# Name: longitude, Length: 5752, dtype: object

# %%
df.dtypes
# Out:
# classificacao                             object
# latitude                                  string
# longitude                                 object
# cidade                                    object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# aerodromo                                 object
# data                              datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# status                                    object
# relatorio_numero                          object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# total_recomendacoes                        int64
# aeronaves_envolvidas                       int64
# ocorrencia_saida_pista                    object
# dtype: object
